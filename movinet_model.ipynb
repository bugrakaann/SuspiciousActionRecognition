# %%
import os
import pandas as pd
import cv2
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import numpy as np

# %%
# Ana dataset klasörü
dataset_path = "./dataset/Videos/Videos/"

# Normal ve Abnormal klasörlerini al
normal_path = os.path.join(dataset_path, "normal")
abnormal_path = os.path.join(dataset_path, "abnormal")

# Tüm sınıfları belirleyelim
abnormal_classes = [folder for folder in os.listdir(abnormal_path) if os.path.isdir(os.path.join(abnormal_path, folder))]
class_to_index = {cls: idx + 1 for idx, cls in enumerate(abnormal_classes)}  # Abnormal sınıfları 1, 2, 3... olarak etiketliyoruz
class_to_index["normal"] = 0  # Normal aktiviteleri 0 olarak etiketliyoruz

# DataFrame oluşturmak için liste
data = []

# Normal videoları ekleyelim
for subfolder in os.listdir(normal_path):
    subfolder_path = os.path.join(normal_path, subfolder)
    if os.path.isdir(subfolder_path):
        videos = [os.path.join(subfolder_path, v) for v in os.listdir(subfolder_path) if v.endswith(('.mp4', '.avi', '.mov'))]
        data.extend([(video, "normal", 0) for video in videos])  # Label = 0

# Abnormal videoları ekleyelim
for subfolder in abnormal_classes:
    subfolder_path = os.path.join(abnormal_path, subfolder)
    videos = [os.path.join(subfolder_path, v) for v in os.listdir(subfolder_path) if v.endswith(('.mp4', '.avi', '.mov'))]
    data.extend([(video, subfolder, class_to_index[subfolder]) for video in videos])  # Label = 1, 2, 3, ...

# DataFrame oluştur
df = pd.DataFrame(data, columns=["video_path", "category", "label"])

# %%
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df["label"],random_state=42)

print(f"Train set {len(train_df)} videos")
print(f"Test set {len(test_df)} videos")
# Out:
# Train set 2224 videos
# Test set 556 videos

# %% [markdown]
# # Buraya preprocessing adımı olarak Veri döndürme, zoomout, kontrast vs eklenebilir

# %%
import torch
import torchvision
import torch.nn.functional as F
from torch.utils.data import Dataset

class VideoDataset(Dataset):
    def __init__(self, df, num_frames=8, transform=None, resize_size=(192, 192)):
        self.df = df
        self.num_frames = num_frames
        self.transform = transform
        self.resize_size = resize_size  # Sabit video boyutu (H, W)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        video_path = self.df.iloc[idx]["video_path"]
        label = self.df.iloc[idx]["label"]

        # GPU hızlandırmalı video okuma
        frames = self.extract_frames(video_path, self.num_frames)

        # Eğer transform varsa uygula
        if self.transform:
            frames = self.transform(frames)

        return frames, torch.tensor(label, dtype=torch.long)

    def extract_frames(self, video_path, num_frames):
        vr = torchvision.io.VideoReader(video_path, "video")
        vr.set_current_stream("video")  # Video stream'ini seç

        frames = []
        for frame in vr:
            frame = frame['data'].float() / 255.0  # Normalize (C, H, W)

            # Frame boyutlarını MoviNet'e uygun hale getir
            frame = F.interpolate(frame.unsqueeze(0), size=self.resize_size, mode="bilinear", align_corners=False)
            frame = frame.squeeze(0).permute(1, 2, 0)  # (C, H, W) → (H, W, C)

            frames.append(frame)

            if len(frames) >= num_frames:
                break

        # Eğer video kısa ise son frame ile tamamla
        while len(frames) < num_frames:
            frames.append(frames[-1].clone())

        frames = torch.stack(frames)  # (T, H, W, C) olacak şekilde birleştir
        frames = frames[:num_frames]  # Sabit sayıda frame al (T, H, W, C)

        frames = frames.permute(3, 0, 1, 2)  # (T, H, W, C) → (C, T, H, W)

        return frames.to("cpu", dtype=torch.float16)  # 🔥 **Veriyi float16 yap!**

# %%
train_dataset = VideoDataset(train_df, num_frames=32)
test_dataset = VideoDataset(test_df, num_frames=32)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

print(f"Train loader {len(train_loader)} batches")
print(f"Test loader {len(test_loader)} batches")
# Out:
# Train loader 139 batches
# Test loader 35 batches

# %%
for videos, labels in train_loader:
    print(f"Videos shape:{videos.shape}, Labels shape: {labels.shape}, dtype: {videos.dtype}")
    break;
# Out:
# Videos shape:torch.Size([16, 3, 32, 192, 192]), Labels shape: torch.Size([16]), dtype: torch.float16

# %%
# Movinet Modelini Yükleme
import torch
from movinets import MoViNet
from movinets.config import _C as config

model = MoViNet(config.MODEL.MoViNetA0, causal = True, pretrained = True )
model.to("cpu")
# Out:
# MoViNet(
#   (conv1): ConvBlock3D(
#     (conv_1): Conv2dBNActivation(
#       (conv2d): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (norm): BatchNorm2d(8, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): Hardswish()
#     )
#   )
#   (blocks): Sequential(
#     (b0_l0): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(8, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(24, 24, kernel_size=(5, 5), stride=(2, 2), groups=24, bias=False)
#           (norm): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(48, 16, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(16, 24, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(24, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(8, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#       (res): Sequential(
#         (0): tfAvgPool3D(
#           (avgf): AvgPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=0)
#         )
#         (1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(8, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act): Identity()
#           )
#         )
#       )
#     )
#     (b1_l0): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(8, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 80, kernel_size=(3, 3), stride=(2, 2), groups=80, bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 80, kernel_size=(3, 1), stride=(1, 1), groups=80, bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(160, 40, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#       (res): Sequential(
#         (0): tfAvgPool3D(
#           (avgf): AvgPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=0)
#         )
#         (1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act): Identity()
#           )
#         )
#       )
#     )
#     (b1_l1): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(32, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), groups=80, bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 80, kernel_size=(3, 1), stride=(1, 1), groups=80, bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(160, 40, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b1_l2): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(32, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), groups=80, bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 80, kernel_size=(3, 1), stride=(1, 1), groups=80, bias=False)
#           (norm): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(160, 40, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(80, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b2_l0): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(32, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 3), stride=(2, 2), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(5, 1), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(368, 96, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(96, 184, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#       (res): Sequential(
#         (0): tfAvgPool3D(
#           (avgf): AvgPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=0)
#         )
#         (1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(32, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act): Identity()
#           )
#         )
#       )
#     )
#     (b2_l1): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(112, 112, kernel_size=(3, 3), stride=(1, 1), groups=112, bias=False)
#           (norm): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(112, 112, kernel_size=(3, 1), stride=(1, 1), groups=112, bias=False)
#           (norm): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(224, 56, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b2_l2): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(56, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 1), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(368, 96, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(96, 184, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b3_l0): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(56, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(5, 1), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(368, 96, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(96, 184, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b3_l1): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(56, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 1), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(368, 96, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(96, 184, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b3_l2): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(56, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 1), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(368, 96, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(96, 184, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b3_l3): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(56, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 184, kernel_size=(3, 1), stride=(1, 1), groups=184, bias=False)
#           (norm): BatchNorm2d(184, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(368, 96, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(96, 184, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(184, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(56, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b4_l0): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(56, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), groups=384, bias=False)
#           (norm): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#         (conv_2): Conv2dBNActivation(
#           (conv2d): Conv2d(384, 384, kernel_size=(5, 1), stride=(1, 1), groups=384, bias=False)
#           (norm): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(384, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(104, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#       (res): Sequential(
#         (0): tfAvgPool3D(
#           (avgf): AvgPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=0)
#         )
#         (1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(56, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(104, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (act): Identity()
#           )
#         )
#       )
#     )
#     (b4_l1): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(104, 280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(280, 280, kernel_size=(5, 5), stride=(1, 1), groups=280, bias=False)
#           (norm): BatchNorm2d(280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(560, 144, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(144, 280, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(280, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(104, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b4_l2): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(104, 280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(280, 280, kernel_size=(5, 5), stride=(1, 1), groups=280, bias=False)
#           (norm): BatchNorm2d(280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(560, 144, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(144, 280, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(280, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(104, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#     (b4_l3): BasicBneck(
#       (expand): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(104, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (deep): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(344, 344, kernel_size=(5, 5), stride=(1, 1), groups=344, bias=False)
#           (norm): BatchNorm2d(344, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Hardswish()
#         )
#       )
#       (se): SqueezeExcitation(
#         (temporal_cumualtive_GAvg3D): TemporalCGAvgPool3D()
#         (fc1): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(688, 176, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#         (activation_1): Hardswish()
#         (activation_2): Hardsigmoid()
#         (fc2): ConvBlock3D(
#           (conv_1): Conv2dBNActivation(
#             (conv2d): Conv2d(176, 344, kernel_size=(1, 1), stride=(1, 1))
#             (norm): Identity()
#             (act): Identity()
#           )
#         )
#       )
#       (project): ConvBlock3D(
#         (conv_1): Conv2dBNActivation(
#           (conv2d): Conv2d(344, 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm): BatchNorm2d(104, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act): Identity()
#         )
#       )
#     )
#   )
#   (conv7): ConvBlock3D(
#     (conv_1): Conv2dBNActivation(
#       (conv2d): Conv2d(104, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm): BatchNorm2d(480, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): Hardswish()
#     )
#   )
#   (classifier): Sequential(
#     (0): ConvBlock3D(
#       (conv_1): Conv2dBNActivation(
#         (conv2d): Conv2d(480, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (norm): Identity()
#         (act): Identity()
#       )
#     )
#     (1): Swish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): ConvBlock3D(
#       (conv_1): Conv2dBNActivation(
#         (conv2d): Conv2d(2048, 600, kernel_size=(1, 1), stride=(1, 1))
#         (norm): Identity()
#         (act): Identity()
#       )
#     )
#   )
#   (cgap): TemporalCGAvgPool3D()
# )

# %%
#Çıkış katmanlarını düzenleme
num_classes = len(train_df["category"].unique())

model.classifier[3] = torch.nn.Linear(in_features=2048, out_features=num_classes)

# %% [markdown]
# print(model.blocks[-1].proj)
# import torch
#
# model = model.to("cpu")
# dummy_input = torch.randn(1, 3, 16, 160, 160)
#
# torch.onnx.export(model, dummy_input, "x3d_xs.onnx", opset_version=11
#                   ,do_constant_folding=True, input_names=["input"], output_names=["output"])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 🎯 Loss & Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-3)  # Weight decay ile overfitting'i önle

# ⚡ Yeni PyTorch Formatına Uygun AMP (Automatic Mixed Precision)
scaler = torch.amp.GradScaler()

# 🛑 Early Stopping Parametreleri
patience = 3  # Kaç epoch boyunca iyileşme olmazsa durdursun
min_delta = 0.01  # İyileşme için gereken minimum fark
best_loss = float("inf")  # En iyi validation loss başta sonsuz olarak ayarlanır
counter = 0  # İyileşme olmayan epoch sayısı
accuracy_threshold = 85.0  # Accuracy'nin geçmesi gereken eşik

# 📌 MoviNet INPUT FORMAT: (B, C, T, H, W)
num_frames = 8  # MoviNet genelde 8 frame kullanıyor, bunu **dataloader ile eşleştir**
input_size = (192, 192)  # MoviNet için standart giriş boyutu

for epoch in range(40):
    model.train()
    running_loss = 0.0

    for videos, labels in train_loader:
        videos, labels = videos.to("cpu"), labels.to("cpu")

        optimizer.zero_grad()
        with torch.amp.autocast("cpu"):
            outputs = model(videos)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()

    train_loss = running_loss / len(train_loader)  # Train loss'u hesapla

    # 📌 VALIDATION AŞAMASI
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for videos, labels in test_loader:
            videos, labels = videos.to("cpu"), labels.to("cpu")
            outputs = model(videos)
            loss = criterion(outputs, labels)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 32
#      30 optimizer.zero_grad()
#      31 with torch.amp.autocast("cpu"):
# ---> 32     outputs = model(videos)
#      33     loss = criterion(outputs, labels)
#      35 scaler.scale(loss).backward()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\movinets\models.py:651, in MoViNet.forward(self, x)
#     650 def forward(self, x: Tensor) -> Tensor:
# --> 651     return self._forward_impl(x)
#
# File ~\anaconda3\Lib\site-packages\movinets\models.py:645, in MoViNet._forward_impl(self, x)
#     643 x = self.conv7(x)
#     644 x = self.avg(x)
# --> 645 x = self.classifier(x)
#     646 x = x.flatten(1)
#     648 return x
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (32768x1 and 2048x12)
